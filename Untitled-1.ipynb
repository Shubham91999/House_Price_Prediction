# %%
#Importing required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Reading data from housing.csv file
data = pd.read_csv('housing.csv')
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20640 rows x 10 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %% [markdown]
# #### Total number of rows is 20640. All the columns other than total_bedrooms contain 20640 non-null values, it means there are some null values in that column.
# #### As the number of null values is less comparatively, lets drop the rows with null values.

# %%
#Droppping the null values, keeping inplace true to make changes in original dataframe
data.dropna(inplace=True)
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20433 rows x 10 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20433 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20433 non-null  float64
#  1   latitude            20433 non-null  float64
#  2   housing_median_age  20433 non-null  float64
#  3   total_rooms         20433 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20433 non-null  float64
#  6   households          20433 non-null  float64
#  7   median_income       20433 non-null  float64
#  8   median_house_value  20433 non-null  float64
#  9   ocean_proximity     20433 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.7+ MB

# %%
#Importing train test split from sklearn
from sklearn.model_selection import train_test_split

# %%
#Creating x,y data for the model
X = data.drop(['median_house_value'], axis=1)
y = data['median_house_value']

# %%
X
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income ocean_proximity
# 0           322.0       126.0         8.3252        NEAR BAY
# 1          2401.0      1138.0         8.3014        NEAR BAY
# 2           496.0       177.0         7.2574        NEAR BAY
# 3           558.0       219.0         5.6431        NEAR BAY
# 4           565.0       259.0         3.8462        NEAR BAY
# ...           ...         ...            ...             ...
# 20635       845.0       330.0         1.5603          INLAND
# 20636       356.0       114.0         2.5568          INLAND
# 20637      1007.0       433.0         1.7000          INLAND
# 20638       741.0       349.0         1.8672          INLAND
# 20639      1387.0       530.0         2.3886          INLAND
#
# [20433 rows x 9 columns]

# %%
y
# Out:
# 0        452600.0
# 1        358500.0
# 2        352100.0
# 3        341300.0
# 4        342200.0
#            ...
# 20635     78100.0
# 20636     77100.0
# 20637     92300.0
# 20638     84700.0
# 20639     89400.0
# Name: median_house_value, Length: 20433, dtype: float64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
train_data = X_train.join(y_train)

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 13018    -121.20     38.69                26.0       3077.0           607.0
# 12290    -116.97     33.94                29.0       3197.0           632.0
# 3222     -119.66     36.32                24.0       2652.0           568.0
# 17288    -119.74     34.38                32.0       1479.0           287.0
# 20039    -118.97     36.06                26.0       1289.0           262.0
# ...          ...       ...                 ...          ...             ...
# 1707     -122.31     37.94                38.0       1794.0           349.0
# 10219    -117.88     33.89                16.0        959.0           176.0
# 11537    -118.00     33.76                26.0       1876.0           455.0
# 19199    -122.70     38.44                42.0        709.0           182.0
# 20541    -121.70     38.54                13.0       6819.0          1158.0
#
#        population  households  median_income ocean_proximity  \
# 13018      1603.0       595.0         2.7174          INLAND
# 12290      1722.0       603.0         3.0432          INLAND
# 3222       1532.0       445.0         2.3256          INLAND
# 17288       830.0       288.0         5.3450      NEAR OCEAN
# 20039      1100.0       244.0         1.9750          INLAND
# ...           ...         ...            ...             ...
# 1707        810.0       335.0         3.8343        NEAR BAY
# 10219       353.0       185.0         4.5000       <1H OCEAN
# 11537      1499.0       436.0         2.9250       <1H OCEAN
# 19199       547.0       172.0         2.1912       <1H OCEAN
# 20541      2828.0      1115.0         4.6225          INLAND
#
#        median_house_value
# 13018            137500.0
# 12290             91200.0
# 3222              56800.0
# 17288            322600.0
# 20039             51400.0
# ...                   ...
# 1707             191400.0
# 10219            173300.0
# 11537            176000.0
# 19199            165000.0
# 20541            226500.0
#
# [16346 rows x 10 columns]

# %%
train_data.hist(figsize=(15,8))
plt.show()

# %%
train_data.drop(['ocean_proximity'], axis=1).corr()
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.924732           -0.110661     0.043120
# latitude            -0.924732  1.000000            0.013163    -0.034106
# housing_median_age  -0.110661  0.013163            1.000000    -0.360860
# total_rooms          0.043120 -0.034106           -0.360860     1.000000
# total_bedrooms       0.069619 -0.066218           -0.321081     0.930160
# population           0.100659 -0.109224           -0.301949     0.860740
# households           0.056638 -0.071187           -0.304697     0.919376
# median_income       -0.021223 -0.074629           -0.115639     0.197939
# median_house_value  -0.047539 -0.142559            0.110934     0.135820
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.069619    0.100659    0.056638      -0.021223
# latitude                 -0.066218   -0.109224   -0.071187      -0.074629
# housing_median_age       -0.321081   -0.301949   -0.304697      -0.115639
# total_rooms               0.930160    0.860740    0.919376       0.197939
# total_bedrooms            1.000000    0.881667    0.979666      -0.008662
# population                0.881667    1.000000    0.911594       0.005319
# households                0.979666    0.911594    1.000000       0.013252
# median_income            -0.008662    0.005319    0.013252       1.000000
# median_house_value        0.051286   -0.022626    0.066845       0.689882
#
#                     median_house_value
# longitude                    -0.047539
# latitude                     -0.142559
# housing_median_age            0.110934
# total_rooms                   0.135820
# total_bedrooms                0.051286
# population                   -0.022626
# households                    0.066845
# median_income                 0.689882
# median_house_value            1.000000

# %%
plt.figure(figsize=(15,8))
sns.heatmap(train_data.drop(['ocean_proximity'], axis=1).corr(), annot=True, cmap='YlGnBu')
# Out:
# <Axes: >

# %% [markdown]
# #### Done with data exploring. Now, lets start data preprocessing.

# %%
#Using pandas one hot encoding
pd.get_dummies(train_data.ocean_proximity, dtype=int)
# Out:
#        <1H OCEAN  INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 13018          0       1       0         0           0
# 12290          0       1       0         0           0
# 3222           0       1       0         0           0
# 17288          0       0       0         0           1
# 20039          0       1       0         0           0
# ...          ...     ...     ...       ...         ...
# 1707           0       0       0         1           0
# 10219          1       0       0         0           0
# 11537          1       0       0         0           0
# 19199          1       0       0         0           0
# 20541          0       1       0         0           0
#
# [16346 rows x 5 columns]

# %%
#Joining the dummies with training data
train_data = train_data.join(pd.get_dummies(train_data.ocean_proximity, dtype=int)).drop(['ocean_proximity'], axis=1)

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 13018    -121.20     38.69                26.0       3077.0           607.0
# 12290    -116.97     33.94                29.0       3197.0           632.0
# 3222     -119.66     36.32                24.0       2652.0           568.0
# 17288    -119.74     34.38                32.0       1479.0           287.0
# 20039    -118.97     36.06                26.0       1289.0           262.0
# ...          ...       ...                 ...          ...             ...
# 1707     -122.31     37.94                38.0       1794.0           349.0
# 10219    -117.88     33.89                16.0        959.0           176.0
# 11537    -118.00     33.76                26.0       1876.0           455.0
# 19199    -122.70     38.44                42.0        709.0           182.0
# 20541    -121.70     38.54                13.0       6819.0          1158.0
#
#        population  households  median_income  median_house_value  <1H OCEAN  \
# 13018      1603.0       595.0         2.7174            137500.0          0
# 12290      1722.0       603.0         3.0432             91200.0          0
# 3222       1532.0       445.0         2.3256             56800.0          0
# 17288       830.0       288.0         5.3450            322600.0          0
# 20039      1100.0       244.0         1.9750             51400.0          0
# ...           ...         ...            ...                 ...        ...
# 1707        810.0       335.0         3.8343            191400.0          0
# 10219       353.0       185.0         4.5000            173300.0          1
# 11537      1499.0       436.0         2.9250            176000.0          1
# 19199       547.0       172.0         2.1912            165000.0          1
# 20541      2828.0      1115.0         4.6225            226500.0          0
#
#        INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 13018       1       0         0           0
# 12290       1       0         0           0
# 3222        1       0         0           0
# 17288       0       0         0           1
# 20039       1       0         0           0
# ...       ...     ...       ...         ...
# 1707        0       0         1           0
# 10219       0       0         0           0
# 11537       0       0         0           0
# 19199       0       0         0           0
# 20541       1       0         0           0
#
# [16346 rows x 14 columns]

# %%
plt.figure(figsize=(15,8))
sns.heatmap(train_data.corr(), annot=True, cmap='YlGnBu')
# Out:
# <Axes: >

# %%
plt.figure(figsize=(15,8))
sns.scatterplot(x='latitude', y='longitude', data=train_data, hue='median_house_value', palette='coolwarm')
# Out:
# <Axes: xlabel='latitude', ylabel='longitude'>

# %% [markdown]
# #### Here, we can see the houses near the coastline have higher median house value as compared to the ones in inland area.

# %% [markdown]
# #### Started with feature engineering

# %%
train_data['bedroom_ratio'] = train_data['total_bedrooms'] / train_data['total_rooms']
train_data['household_rooms'] = train_data['total_rooms'] / train_data['households']

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 13018    -121.20     38.69                26.0       3077.0           607.0
# 12290    -116.97     33.94                29.0       3197.0           632.0
# 3222     -119.66     36.32                24.0       2652.0           568.0
# 17288    -119.74     34.38                32.0       1479.0           287.0
# 20039    -118.97     36.06                26.0       1289.0           262.0
# ...          ...       ...                 ...          ...             ...
# 1707     -122.31     37.94                38.0       1794.0           349.0
# 10219    -117.88     33.89                16.0        959.0           176.0
# 11537    -118.00     33.76                26.0       1876.0           455.0
# 19199    -122.70     38.44                42.0        709.0           182.0
# 20541    -121.70     38.54                13.0       6819.0          1158.0
#
#        population  households  median_income  median_house_value  <1H OCEAN  \
# 13018      1603.0       595.0         2.7174            137500.0          0
# 12290      1722.0       603.0         3.0432             91200.0          0
# 3222       1532.0       445.0         2.3256             56800.0          0
# 17288       830.0       288.0         5.3450            322600.0          0
# 20039      1100.0       244.0         1.9750             51400.0          0
# ...           ...         ...            ...                 ...        ...
# 1707        810.0       335.0         3.8343            191400.0          0
# 10219       353.0       185.0         4.5000            173300.0          1
# 11537      1499.0       436.0         2.9250            176000.0          1
# 19199       547.0       172.0         2.1912            165000.0          1
# 20541      2828.0      1115.0         4.6225            226500.0          0
#
#        INLAND  ISLAND  NEAR BAY  NEAR OCEAN  bedroom_ratio  household_rooms
# 13018       1       0         0           0       0.197270         5.171429
# 12290       1       0         0           0       0.197685         5.301824
# 3222        1       0         0           0       0.214178         5.959551
# 17288       0       0         0           1       0.194050         5.135417
# 20039       1       0         0           0       0.203258         5.282787
# ...       ...     ...       ...         ...            ...              ...
# 1707        0       0         1           0       0.194537         5.355224
# 10219       0       0         0           0       0.183525         5.183784
# 11537       0       0         0           0       0.242537         4.302752
# 19199       0       0         0           0       0.256700         4.122093
# 20541       1       0         0           0       0.169820         6.115695
#
# [16346 rows x 16 columns]

# %%
plt.figure(figsize=(15,8))
sns.heatmap(train_data.corr(), annot=True, cmap='YlGnBu')
# Out:
# <Axes: >
