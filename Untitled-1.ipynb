# %%
#Importing required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Reading data from housing.csv file
data = pd.read_csv('housing.csv')
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20640 rows x 10 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %% [markdown]
# #### Total number of rows is 20640. All the columns other than total_bedrooms contain 20640 non-null values, it means there are some null values in that column.
# #### As the number of null values is less comparatively, lets drop the rows with null values.

# %%
#Droppping the null values, keeping inplace true to make changes in original dataframe
data.dropna(inplace=True)
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20433 rows x 10 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20433 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20433 non-null  float64
#  1   latitude            20433 non-null  float64
#  2   housing_median_age  20433 non-null  float64
#  3   total_rooms         20433 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20433 non-null  float64
#  6   households          20433 non-null  float64
#  7   median_income       20433 non-null  float64
#  8   median_house_value  20433 non-null  float64
#  9   ocean_proximity     20433 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.7+ MB

# %%
#Importing train test split from sklearn
from sklearn.model_selection import train_test_split

# %%
#Creating x,y data for the model
X = data.drop(['median_house_value'], axis=1)
y = data['median_house_value']

# %%
X
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income ocean_proximity
# 0           322.0       126.0         8.3252        NEAR BAY
# 1          2401.0      1138.0         8.3014        NEAR BAY
# 2           496.0       177.0         7.2574        NEAR BAY
# 3           558.0       219.0         5.6431        NEAR BAY
# 4           565.0       259.0         3.8462        NEAR BAY
# ...           ...         ...            ...             ...
# 20635       845.0       330.0         1.5603          INLAND
# 20636       356.0       114.0         2.5568          INLAND
# 20637      1007.0       433.0         1.7000          INLAND
# 20638       741.0       349.0         1.8672          INLAND
# 20639      1387.0       530.0         2.3886          INLAND
#
# [20433 rows x 9 columns]

# %%
y
# Out:
# 0        452600.0
# 1        358500.0
# 2        352100.0
# 3        341300.0
# 4        342200.0
#            ...
# 20635     78100.0
# 20636     77100.0
# 20637     92300.0
# 20638     84700.0
# 20639     89400.0
# Name: median_house_value, Length: 20433, dtype: float64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
train_data = X_train.join(y_train)

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 15355    -117.32     33.25                 7.0       8206.0          1523.0
# 9296     -122.55     38.03                29.0       7174.0          1169.0
# 19367    -123.07     38.46                31.0        855.0           217.0
# 4726     -118.37     34.05                52.0       1563.0           306.0
# 16832    -122.50     37.59                36.0       1521.0           253.0
# ...          ...       ...                 ...          ...             ...
# 8830     -118.37     34.09                38.0       1349.0           344.0
# 3407     -118.30     34.25                44.0       1442.0           285.0
# 89       -122.27     37.80                52.0        249.0            78.0
# 18478    -121.63     37.10                14.0       5034.0           797.0
# 1154     -121.49     39.52                25.0        848.0           153.0
#
#        population  households  median_income ocean_proximity  \
# 15355      4399.0      1423.0         3.6301       <1H OCEAN
# 9296       3063.0      1172.0         6.0902        NEAR BAY
# 19367       280.0       139.0         2.3611      NEAR OCEAN
# 4726        776.0       308.0         3.6250       <1H OCEAN
# 16832       736.0       241.0         4.3542      NEAR OCEAN
# ...           ...         ...            ...             ...
# 8830        547.0       309.0         3.2159       <1H OCEAN
# 3407        859.0       292.0         4.5833       <1H OCEAN
# 89          396.0        85.0         1.2434        NEAR BAY
# 18478      2124.0       790.0         4.9028       <1H OCEAN
# 1154        436.0       155.0         3.9028          INLAND
#
#        median_house_value
# 15355            170900.0
# 9296             293200.0
# 19367            112500.0
# 4726             440900.0
# 16832            237500.0
# ...                   ...
# 8830             383300.0
# 3407             197300.0
# 89               500001.0
# 18478            335000.0
# 1154              93800.0
#
# [16346 rows x 10 columns]

# %%
train_data.hist(figsize=(15,8))
plt.show()

# %%
train_data.drop(['ocean_proximity'], axis=1).corr()
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.924005           -0.105180     0.038405
# latitude            -0.924005  1.000000            0.008035    -0.031791
# housing_median_age  -0.105180  0.008035            1.000000    -0.356162
# total_rooms          0.038405 -0.031791           -0.356162     1.000000
# total_bedrooms       0.063874 -0.063641           -0.319519     0.931231
# population           0.094138 -0.105693           -0.291361     0.857197
# households           0.051906 -0.070151           -0.301046     0.921398
# median_income       -0.025079 -0.071372           -0.118123     0.198845
# median_house_value  -0.053395 -0.138117            0.105423     0.133395
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.063874    0.094138    0.051906      -0.025079
# latitude                 -0.063641   -0.105693   -0.070151      -0.071372
# housing_median_age       -0.319519   -0.291361   -0.301046      -0.118123
# total_rooms               0.931231    0.857197    0.921398       0.198845
# total_bedrooms            1.000000    0.877329    0.981024      -0.005456
# population                0.877329    1.000000    0.905654       0.007329
# households                0.981024    0.905654    1.000000       0.016919
# median_income            -0.005456    0.007329    0.016919       1.000000
# median_house_value        0.051205   -0.023589    0.067161       0.684214
#
#                     median_house_value
# longitude                    -0.053395
# latitude                     -0.138117
# housing_median_age            0.105423
# total_rooms                   0.133395
# total_bedrooms                0.051205
# population                   -0.023589
# households                    0.067161
# median_income                 0.684214
# median_house_value            1.000000

# %%
plt.figure(figsize=(15,8))
sns.heatmap(train_data.drop(['ocean_proximity'], axis=1).corr(), annot=True, cmap='YlGnBu')
# Out:
# <Axes: >

# %% [markdown]
# #### Done with data exploring. Now, lets start data preprocessing.
